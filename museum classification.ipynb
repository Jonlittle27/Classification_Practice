# %%
import pandas as pd
import io
import requests
url="https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2022/2022-11-22/museums.csv"
s=requests.get(url).content
c=pd.read_csv(io.StringIO(s.decode('utf-8')))

# %%
df = c.copy()

df.head()
# Out:
#         museum_id                     Name_of_museum  \
# 0        mm.New.1                    Titanic Belfast
# 1     mm.aim.1230       The Woodland Heritage Museum
# 2  mm.domus.WM019  Warwickshire Museum Of Rural Life
# 3     mm.aim.0484           Battle Of Flowers Museum
# 4     mm.aim.0485                     Jet Age Museum
#
#                    Address_line_1                 Address_line_2  \
# 0                   1 Olympic Way                            NaN
# 1                             NaN                    Brokerswood
# 2  Warwick College of Agriculture  Horticulture & Equine Studies
# 3                     La Robeline               Mont des Corvees
# 4                  57 Crown Drive                 Bishops Cleeve
#
#   Village,_Town_or_City  Postcode   Latitude  Longitude  \
# 0               Belfast   BT3 9EP  54.608080  -5.909915
# 1           nr Westbury  BA13 4EH  51.270903  -2.231863
# 2       Moreton Morrell  CV35 9BL  52.197146  -1.555528
# ...

# %%
df["Accreditation"].value_counts()
# Out:
# Unaccredited    2471
# Accredited      1720
# Name: Accreditation, dtype: int64

# %%
1720 +2471
# Out:
# 4191

# %%
1720 / 4191
# Out:
# 0.41040324504891434
